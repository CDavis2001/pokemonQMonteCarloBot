# %%
import matplotlib.pyplot as plt
import numpy as np
import json

file = open("formattedresults.json")
results = json.load(file)
file.close()


# QLearn
plt.boxplot([results["results"]["QLearningLitePla 1"]["win_util"],results["results"]["QLearningLitePla 1"]["loss_util"]], vert=False)
plt.title("Q Learning Agent")
plt.xlabel("End State Utility")
plt.ylabel("Win and Loss")
plt.show()

# Monte Carlo
plt.boxplot([results["results"]["MonteCarloPlayer 1"]["win_util"],results["results"]["MonteCarloPlayer 1"]["loss_util"]], vert=False)
plt.title("Monte Carlo Search Agent")
plt.xlabel("End State Utility")
plt.ylabel("Win and Loss")
plt.show()
    
# Hybrid Turn
plt.boxplot([results["results"]["HybridTurnSwitch 1"]["win_util"],results["results"]["HybridTurnSwitch 1"]["loss_util"]], vert=False)
plt.title("Hybrid Turn Switch Agent")
plt.xlabel("End State Utility")
plt.ylabel("Win and Loss")
plt.show()

    
# Hybrid HP
plt.boxplot([results["results"]["HybridHPSwitchPl 1"]["win_util"],results["results"]["HybridHPSwitchPl 1"]["loss_util"]], vert=False)
plt.title("Hybrid HP Switch Agent")
plt.xlabel("End State Utility")
plt.ylabel("Win and Loss")
plt.show()

# Hybrid Info
plt.boxplot([results["results"]["HybridInfoSwitch 1"]["win_util"],results["results"]["HybridInfoSwitch 1"]["loss_util"]], vert=False)
plt.title("Hybrid Info Switch Agent")
plt.xlabel("End State Utility")
plt.ylabel("Win and Loss")
plt.show()

# %%
from tabulate import tabulate
x = ["MaxDamagePlanPla 1", "QLearningLitePla 1", "MonteCarloPlayer 1", "HybridTurnSwitch 1", "HybridHPSwitchPl 1", "HybridInfoSwitch 1"]
y = ["MaxDamagePlanPla 1", "QLearningLitePla 1", "MonteCarloPlayer 1", "HybridTurnSwitch 1", "HybridHPSwitchPl 1", "HybridInfoSwitch 1"]


winrates = []
for i in range(6):
    winrates.append([])
    for j in range(6):
        try:
            wins = results["results"][x[i]][y[j]]["wins"]
            losses = results["results"][x[i]][y[j]]["losses"]
            total = wins + losses
            winrate = wins/total
            winrates[i].append(winrate * 100)
        except:
            winrates[i].append("N/A")
        
            


print(tabulate(winrates))
# Out:
# ------------------  ------------------  ------------------  -----------------  ------------------  ------------------
# N/A                 95.97714829802429   97.58837132474397   100.0              93.54838709677419   100.0
# 4.02285170197572    N/A                 14.914772727272727  22.58064516129032  48.275862068965516  42.857142857142854
# 2.4116286752560288  85.08522727272727   N/A                 41.17647058823529  76.66666666666667   68.96551724137932
# 0.0                 77.41935483870968   58.82352941176471   N/A                N/A                 N/A
# 6.451612903225806   51.724137931034484  23.333333333333332  N/A                N/A                 N/A
# 0.0                 57.14285714285714   31.03448275862069   N/A                N/A                 N/A
# ------------------  ------------------  ------------------  -----------------  ------------------  ------------------

# %%
file = open("qvaluetracking/QLite.txt", "r")
data = dict()
states = []

line_num = 0
while True:
    line_num += 1
    if line_num % 10000 == 0:
        print(line_num)
        
    line = file.readline()
    if not line:
        break
    point = line.split(";")
    if len(point) != 3:
        continue
    if not point[0] in states:
        states.append(point[0])
        data[point[0]] = [float(point[1]), float(point[2].strip())]
    else:
        if point[1] == point[2]:
            continue
        else:
            data[point[0]].append(float(point[2].strip()))
                
    
file.close()
longest = [[]]*100
lengths= [0]*100
count = 0
for key in data:
    longest.append(data[key])

file = open("longest.txt", "w")
for i in range(10):
    maxList = max(longest, key= len)
    file.write(str(maxList))
    file.write("\n")
    longest.remove(maxList)

file.close()
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000

# %%
import numpy as np
allY = [[0,1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 1.1029003927251966, 0.02058007854503896, 7.216449660063518e-16, 0.019999999999999032, 0.4435929068672901, 0.21174383187542356, 1.3150496],
[0,0.9348799999999996, -0.11302400000000035, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.507872, 0.507872, 0.507872, 0.507872, 0.507872, 0.507872, 0.507872, 0.507872, 0.507872, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.24000000000000005, 0.5659688755200001, 0.8000000000000002, 0.07788848401067805],
[0,1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 1.1800000000000017, 0.03600000000000114, 0.0, -8.881784197001252e-16, -0.79],
[0,0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 0.20000000000000018, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.059275385003898, 1.0218860881101834, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, 0.6824492244408235, -0.06403679129600001, 0.19599999999999992, 0.0, 0.6000000000000001],
[0,0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.4457599999999996, 0.32277120000000026, 0.24999999999999956],
[0,1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 1.0987738815367087, 0.9359050483073417, 0.4478929691736041, 0.4381907809086814],
[0.0, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.11000000000000032, 0.7277071129446759, 1.0149439999999998],
[0.0, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.17744896, 0.23548979200000017, 0.4595199999999997, 0.5048799999999996, -0.8041599999999998],
[0.0, 0.5287999999999997, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.6537606399999998, 0.23075212799999956, 0.3000000000000007],
[0.0, -0.30000000000000016, 0.0, -1.1266810777599994, -0.4964302694399998, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 0.5128000000000001, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0777062704942582, 1.0037318878016264]]



for i in range(5):
    x = np.linspace(start=0,stop=len(allY[i]),num=len(allY[i]))
    plt.plot(x,allY[i])


plt.xlabel("Observations")
plt.ylabel("Q Value")
plt.show()
